# %%
from tkinter import *
import tkinter.messagebox
import pandas as pd #data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np

from tkinter import filedialog
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

data = pd.read_csv('data/clean-data.csv', index_col=False)
data.drop('Unnamed: 0',axis=1, inplace=True)

array = data.values

X = array[:,1:31]
y = array[:,0]

le = LabelEncoder()
y = le.fit_transform(y)

scaler = StandardScaler()
Xs = scaler.fit_transform(X)

# 5. Divide records in training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(Xs, y, test_size=0.3, random_state=2, stratify=y)

# 6. Create an SVM classifier and train it on 70% of the data set.
X_train = Xs
y_train = y
clf = SVC(probability=True)
model=clf.fit(X_train, y_train)
print('\nSVC score on test data set: %f\n' % model.score(X_test,y_test))
model2 = LogisticRegression()
model2=model2.fit(X_train, y_train)
print('\nLogisticRegression score on test data set: %f\n' % model2.score(X_test,y_test))

def result():
    global model
    try:
        test_data=[]
        test_data.append((var_1.get()-data.radius_mean.mean())/data.radius_mean.std())
        test_data.append((var_2.get()-data.texture_mean.mean())/data.texture_mean.std())
        test_data.append((var_3.get()-data.perimeter_mean.mean())/data.perimeter_mean.std())
        test_data.append((var_4.get()-data.area_mean.mean())/data.area_mean.std())
        test_data.append((var_5.get()-data.smoothness_mean.mean())/data.smoothness_mean.std())
        test_data.append((var_6.get()-data.compactness_mean.mean())/data.compactness_mean.std())
        test_data.append((var_7.get()-data.concavity_mean.mean())/data.concavity_mean.std())
        test_data.append((var_8.get()-data['concave points_mean'].mean())/data['concave points_mean'].std())
        test_data.append((var_9.get()-data.symmetry_mean.mean())/data.symmetry_mean.std())
        test_data.append((var_10.get()-data.fractal_dimension_mean.mean())/data.fractal_dimension_mean.std())
        test_data.append((var_11.get()-data.radius_se.mean())/data.radius_se.std())
        test_data.append((var_12.get()-data.texture_se.mean())/data.texture_se.std())
        test_data.append((var_13.get()-data.perimeter_se.mean())/data.perimeter_se.std())
        test_data.append((var_14.get()-data.area_se.mean())/data.area_se.std())
        test_data.append((var_15.get()-data.smoothness_se.mean())/data.smoothness_se.std())
        test_data.append((var_16.get()-data.compactness_se.mean())/data.compactness_se.std())
        test_data.append((var_17.get()-data.concavity_se.mean())/data.concavity_se.std())
        test_data.append((var_18.get()-data['concave points_se'].mean())/data['concave points_se'].std())
        test_data.append((var_19.get()-data.symmetry_se.mean())/data.symmetry_se.std())
        test_data.append((var_20.get()-data.fractal_dimension_se.mean())/data.fractal_dimension_se.std())
        test_data.append((var_21.get()-data.radius_worst.mean())/data.radius_worst.std())
        test_data.append((var_22.get()-data.texture_worst.mean())/data.texture_worst.std())
        test_data.append((var_23.get()-data.perimeter_worst.mean())/data.perimeter_worst.std())
        test_data.append((var_24.get()-data.area_worst.mean())/data.area_worst.std())
        test_data.append((var_25.get()-data.smoothness_worst.mean())/data.smoothness_worst.std())
        test_data.append((var_26.get()-data.compactness_worst.mean())/data.compactness_worst.std())
        test_data.append((var_27.get()-data.concavity_worst.mean())/data.concavity_worst.std())
        test_data.append((var_28.get()-data['concave points_worst'].mean())/data['concave points_worst'].std())
        test_data.append((var_29.get()-data.symmetry_worst.mean())/data.symmetry_worst.std())
        test_data.append((var_30.get()-data.fractal_dimension_worst.mean())/data.fractal_dimension_worst.std())
        x=model.predict_proba([test_data])
        tkinter.messagebox.showinfo( "Your Prediction", "You have {0}% chances of having Breast Cancer".format(int(x[0][1]*100)))
    except Exception:
        tkinter.messagebox.showinfo( "Error", "Please enter valid values.")
        
def result2():
    global model
    try:
        test_data=[]
        test_data.append((var_1.get()-data.radius_mean.mean())/data.radius_mean.std())
        test_data.append((var_2.get()-data.texture_mean.mean())/data.texture_mean.std())
        test_data.append((var_3.get()-data.perimeter_mean.mean())/data.perimeter_mean.std())
        test_data.append((var_4.get()-data.area_mean.mean())/data.area_mean.std())
        test_data.append((var_5.get()-data.smoothness_mean.mean())/data.smoothness_mean.std())
        test_data.append((var_6.get()-data.compactness_mean.mean())/data.compactness_mean.std())
        test_data.append((var_7.get()-data.concavity_mean.mean())/data.concavity_mean.std())
        test_data.append((var_8.get()-data['concave points_mean'].mean())/data['concave points_mean'].std())
        test_data.append((var_9.get()-data.symmetry_mean.mean())/data.symmetry_mean.std())
        test_data.append((var_10.get()-data.fractal_dimension_mean.mean())/data.fractal_dimension_mean.std())
        test_data.append((var_11.get()-data.radius_se.mean())/data.radius_se.std())
        test_data.append((var_12.get()-data.texture_se.mean())/data.texture_se.std())
        test_data.append((var_13.get()-data.perimeter_se.mean())/data.perimeter_se.std())
        test_data.append((var_14.get()-data.area_se.mean())/data.area_se.std())
        test_data.append((var_15.get()-data.smoothness_se.mean())/data.smoothness_se.std())
        test_data.append((var_16.get()-data.compactness_se.mean())/data.compactness_se.std())
        test_data.append((var_17.get()-data.concavity_se.mean())/data.concavity_se.std())
        test_data.append((var_18.get()-data['concave points_se'].mean())/data['concave points_se'].std())
        test_data.append((var_19.get()-data.symmetry_se.mean())/data.symmetry_se.std())
        test_data.append((var_20.get()-data.fractal_dimension_se.mean())/data.fractal_dimension_se.std())
        test_data.append((var_21.get()-data.radius_worst.mean())/data.radius_worst.std())
        test_data.append((var_22.get()-data.texture_worst.mean())/data.texture_worst.std())
        test_data.append((var_23.get()-data.perimeter_worst.mean())/data.perimeter_worst.std())
        test_data.append((var_24.get()-data.area_worst.mean())/data.area_worst.std())
        test_data.append((var_25.get()-data.smoothness_worst.mean())/data.smoothness_worst.std())
        test_data.append((var_26.get()-data.compactness_worst.mean())/data.compactness_worst.std())
        test_data.append((var_27.get()-data.concavity_worst.mean())/data.concavity_worst.std())
        test_data.append((var_28.get()-data['concave points_worst'].mean())/data['concave points_worst'].std())
        test_data.append((var_29.get()-data.symmetry_worst.mean())/data.symmetry_worst.std())
        test_data.append((var_30.get()-data.fractal_dimension_worst.mean())/data.fractal_dimension_worst.std())
        x=model2.predict_proba([test_data])
        tkinter.messagebox.showinfo( "Your Prediction", "You have {0}% chances of having Breast Cancer".format(int(x[0][1]*100)))
    except Exception:
        tkinter.messagebox.showinfo( "Error", "Please enter valid values.")



root=Tk()
root.resizable(0,0)
root.geometry("1000x650")

var_1=DoubleVar()
var_2=DoubleVar()
var_3=DoubleVar()
var_4=DoubleVar()
var_5=DoubleVar()
var_6=DoubleVar()
var_7=DoubleVar()
var_8=DoubleVar()
var_9=DoubleVar()
var_10=DoubleVar()
var_11=DoubleVar()
var_12=DoubleVar()
var_13=DoubleVar()
var_14=DoubleVar()
var_15=DoubleVar()
var_16=DoubleVar()
var_17=DoubleVar()
var_18=DoubleVar()
var_19=DoubleVar()
var_20=DoubleVar()
var_21=DoubleVar()
var_22=DoubleVar()
var_23=DoubleVar()
var_24=DoubleVar()
var_25=DoubleVar()
var_26=DoubleVar()
var_27=DoubleVar()
var_28=DoubleVar()
var_29=DoubleVar()
var_30=DoubleVar()

Label(root,text="Breast Cancer Prediction",font='Arial 16 bold').grid(row=0, sticky='',columnspan=6,padx=50,pady=30)

L1=Label(root,text="Radius Mean").grid(row=1,column=0,sticky=E,ipadx=5)
L2=Label(root,text="Texture Mean").grid(row=1,column=2,sticky=E,ipadx=5)
L3=Label(root,text="Perimeter Mean").grid(row=1,column=4,sticky=E,ipadx=5,padx=5)

L4=Label(root,text="Area Mean").grid(row=2,column=0,sticky=E,ipadx=5)
L5=Label(root,text="Smoothness Mean").grid(row=2,column=2,sticky=E,ipadx=5)
L6=Label(root,text="Compactness Mean").grid(row=2,column=4,sticky=E,ipadx=5,padx=0)

L7=Label(root,text="Concavity Mean").grid(row=3,column=0,sticky=E,ipadx=5)
L8=Label(root,text="Concave Points Mean").grid(row=3,column=2,sticky=E,ipadx=5)
L9=Label(root,text="Symmetry Mean").grid(row=3,column=4,sticky=E,ipadx=5)

L10=Label(root,text="Fractal Dimension Mean").grid(row=4,column=0,sticky=E,ipadx=5)
L11=Label(root,text="Radius Se").grid(row=4,column=2,sticky=E,ipadx=5)
L12=Label(root,text="Texture Se").grid(row=4,column=4,sticky=E,ipadx=5)

L13=Label(root,text="Perimeter Se").grid(row=5,column=0,sticky=E,ipadx=5)
L14=Label(root,text="Area Se").grid(row=5,column=2,sticky=E,ipadx=5,padx=0)
L15=Label(root,text="Smoothness Se").grid(row=5,column=4,sticky=E,ipadx=5)

L16=Label(root,text="Compactness Se").grid(row=6,column=0,sticky=E,ipadx=5)
L17=Label(root,text="Concavity Se").grid(row=6,column=2,sticky=E,ipadx=5)
L18=Label(root,text="Concave Points Se").grid(row=6,column=4,sticky=E,ipadx=5)

L19=Label(root,text="Symmetry Se").grid(row=7,column=0,sticky=E,ipadx=5)
L20=Label(root,text="Fractal Dimension Se").grid(row=7,column=2,sticky=E,ipadx=5)
L21=Label(root,text="Radius Worst").grid(row=7,column=4,sticky=E,ipadx=5,padx=0)

L22=Label(root,text="Texture Worst").grid(row=8,column=0,sticky=E,ipadx=5)
L23=Label(root,text="Perimeter Worst").grid(row=8,column=2,sticky=E,ipadx=5)
L24=Label(root,text="Area Worst").grid(row=8,column=4,sticky=E,ipadx=5)

L25=Label(root,text="Smoothness Worst").grid(row=9,column=0,sticky=E,ipadx=5)
L26=Label(root,text="Compactness Worst").grid(row=9,column=2,sticky=E,ipadx=5)
L27=Label(root,text="Concavity Worst").grid(row=9,column=4,sticky=E,ipadx=5)

L28=Label(root,text="Concave Points Worst").grid(row=10,column=0,sticky=E,ipadx=5,padx=0)
L29=Label(root,text="Symmetry Worst").grid(row=10,column=2,sticky=E,ipadx=5)
L30=Label(root,text="Fractal Dimension Worst").grid(row=10,column=4,sticky=E,ipadx=5)

entry1=Entry(root,width=26, textvariable=var_1).grid(row=1,column=1,ipadx=5,ipady=5,pady=5)
entry2=Entry(root,width=26, textvariable=var_2).grid(row=1,column=3,ipadx=5,ipady=5,pady=5)
entry3=Entry(root,width=26, textvariable=var_3).grid(row=1,column=5,ipadx=5,ipady=5,pady=10)

entry4=Entry(root,width=26, textvariable=var_4).grid(row=2,column=1,ipadx=5,ipady=5,pady=10)
entry5=Entry(root,width=26, textvariable=var_5).grid(row=2,column=3,ipadx=5,ipady=5,pady=10)
entry6=Entry(root,width=26, textvariable=var_6).grid(row=2,column=5,ipadx=5,ipady=5,pady=10)

entry7=Entry(root,width=26, textvariable=var_7).grid(row=3,column=1,ipadx=5,ipady=5,pady=5)
entry8=Entry(root,width=26, textvariable=var_8).grid(row=3,column=3,ipadx=5,ipady=5,pady=10)
entry9=Entry(root,width=26, textvariable=var_9).grid(row=3,column=5,ipadx=5,ipady=5,pady=10)

entry10=Entry(root,width=26, textvariable=var_10).grid(row=4,column=1,ipadx=5,ipady=5,pady=10)
entry11=Entry(root,width=26, textvariable=var_11).grid(row=4,column=3,ipadx=5,ipady=5,pady=5)
entry12=Entry(root,width=26, textvariable=var_12).grid(row=4,column=5,ipadx=5,ipady=5,pady=5)

entry13=Entry(root,width=26, textvariable=var_13).grid(row=5,column=1,ipadx=5,ipady=5,pady=10)
entry14=Entry(root,width=26, textvariable=var_14).grid(row=5,column=3,ipadx=5,ipady=5,pady=10)
entry15=Entry(root,width=26, textvariable=var_15).grid(row=5,column=5,ipadx=5,ipady=5,pady=10)

entry16=Entry(root,width=26, textvariable=var_16).grid(row=6,column=1,ipadx=5,ipady=5,pady=10)
entry17=Entry(root,width=26, textvariable=var_17).grid(row=6,column=3,ipadx=5,ipady=5,pady=5)
entry18=Entry(root,width=26, textvariable=var_18).grid(row=6,column=5,ipadx=5,ipady=5,pady=10)

entry19=Entry(root,width=26, textvariable=var_19).grid(row=7,column=1,ipadx=5,ipady=5,pady=10)
entry20=Entry(root,width=26, textvariable=var_20).grid(row=7,column=3,ipadx=5,ipady=5,pady=10)
entry21=Entry(root,width=26, textvariable=var_21).grid(row=7,column=5,ipadx=5,ipady=5,pady=5)

entry22=Entry(root,width=26, textvariable=var_22).grid(row=8,column=1,ipadx=5,ipady=5,pady=5)
entry23=Entry(root,width=26, textvariable=var_23).grid(row=8,column=3,ipadx=5,ipady=5,pady=10)
entry24=Entry(root,width=26, textvariable=var_24).grid(row=8,column=5,ipadx=5,ipady=5,pady=10)

entry25=Entry(root,width=26, textvariable=var_25).grid(row=9,column=1,ipadx=5,ipady=5,pady=10)
entry26=Entry(root,width=26, textvariable=var_26).grid(row=9,column=3,ipadx=5,ipady=5,pady=10)
entry27=Entry(root,width=26, textvariable=var_27).grid(row=9,column=5,ipadx=5,ipady=5,pady=5)

entry28=Entry(root,width=26, textvariable=var_28).grid(row=10,column=1,ipadx=5,ipady=5,pady=10)
entry29=Entry(root,width=26, textvariable=var_29).grid(row=10,column=3,ipadx=5,ipady=5,pady=10)
entry30=Entry(root,width=26, textvariable=var_30).grid(row=10,column=5,ipadx=5,ipady=5,pady=10)

button1=Button(root,text="SVC Result",bd=0,bg='#FFC300',activebackground = '#FFA895' , command=result )
button1.grid(row=11,column=0,columnspan=3,ipadx=130,ipady=10,pady=10,padx=5)

button2=Button(root,text="Logistic Regression Result",bd=0,bg='#FFC300',activebackground = '#FFA895' , command=result2 )
button2.grid(row=11,column=4,columnspan=3,ipadx=100,ipady=10,pady=10,padx=5)

root.mainloop()
# Out:
# SVC score on test data set: 0.976608
#
#
# LogisticRegression score on test data set: 0.982456
